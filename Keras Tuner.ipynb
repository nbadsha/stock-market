# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, x_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.00
print("x_train.shape:", x_train.shape)
# Out:
# x_train.shape: (60000, 28, 28)

# %%
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner

# %%
def build_model(hp):
  model = keras.Sequential()
  model.add(layers.Flatten(input_shape=(28, 28)))

  model.add(layers.Dense(
      units=hp.Int('units',
                   min_value = 32,
                   max_value = 512,
                   step = 128),
      activation = 'relu'))

  model.add(layers.Dense(10, activation='softmax'))

  model.compile(
      optimizer = keras.optimizers.Adam(
          hp.Choice(
              'learning_rate', values=[1e-2, 1e-4]
          ),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy']
      )
  )
  return model

# %%
tuner = keras_tuner.RandomSearch(build_model,objective = 'val_accuracy',max_trials = 5)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in _populate_initial_space(self)
#     127         try:
# --> 128             self.hypermodel.declare_hyperparameters(hp)
#     129         except NotImplementedError:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py in declare_hyperparameters(self, hp)
#     113     def declare_hyperparameters(self, hp):
# --> 114         raise NotImplementedError
#     115
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-16b215ec1390> in <module>
# ----> 1 tuner = keras_tuner.RandomSearch(build_model,objective = 'val_accuracy',max_trials = 5)
#
# ...

# %%
pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 135 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 37.4 MB/s
# ...

# %%
import keras_tuner
from tensorflow import keras

# %%
def build_model(hp):
  model = keras.Sequential()
  model.add(keras.layers.Dense(
      hp.Choice('units', [8, 16, 32]),
      activation='relu'))
  model.add(keras.layers.Dense(1, activation='relu'))
  model.compile(loss='mse')
  return model

# %%
tuner = keras_tuner.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=1)

# %%
x_train, y_train = [1,2,3,4,5], [2,4,6,8,10]
x_val, y_val = [10,11,12], [20,22,24]

# %%
tuner.search(x_train, y_train, epochs=4, validation_data=(x_val, y_val))
best_model = tuner.get_best_models()[0]
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 8                 |?                 |units
#
# Epoch 1/4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f7a07340c85c> in <module>
# ----> 1 tuner.search(x_train, y_train, epochs=4, validation_data=(x_val, y_val))
#       2 best_model = tuner.get_best_models()[0]
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     181
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#     185             if results is None:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
# ...
